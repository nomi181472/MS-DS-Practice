# %%
import cv2
import dlib
import numpy as np
from imutils import face_utils
from pathlib import Path

# Argument parser

print('[INFO] Starting System...')
print('[INFO] Importing pretrained model...')
pose_predictor_68_point = dlib.shape_predictor("pretrained_model/shape_predictor_68_face_landmarks.dat")
face_encoder = dlib.face_recognition_model_v1("pretrained_model/dlib_face_recognition_resnet_model_v1.dat")
face_detector = dlib.get_frontal_face_detector()
print('[INFO] Pretrained model imported.')

def transform(image, face_locations):
    coord_faces = []
    for face in face_locations:
        rect = face.top(), face.right(), face.bottom(), face.left()
        coord_face = max(rect[0], 0), min(rect[1], image.shape[1]), min(rect[2], image.shape[0]), max(rect[3], 0)
        coord_faces.append(coord_face)
    return coord_faces

def encode_face(image):
    if len(image.shape) != 3:
        print(f"[ERROR] The input image does not have three dimensions. Current shape: {image.shape}")
        return {}

    # Ensure the image is in RGB format
    if image.shape[2] == 4:
        image = cv2.cvtColor(image, cv2.COLOR_RGBA2RGB)
    elif image.shape[2] == 3:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    elif image.shape[2] == 1:
        image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
    else:
        print(f"[ERROR] Unsupported number of channels: {image.shape[2]}.")
        return {}

    # Ensure the image is in the correct format
    if image.dtype != np.uint8:
        image = image.astype(np.uint8)
    
    try:
        gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    except Exception as e:
        print(f"[ERROR] Failed to convert image to grayscale. Error: {e}")
        return {}

    try:
        face_locations = face_detector(gray_image, 1)
    except Exception as e:
        print(f"[ERROR] Failed to detect faces. Error: {e}")
        return {}

    if len(face_locations) == 0:
        print("[WARNING] No faces detected in the image.")
        return {}

    
    landmarks_list = []
    for face_location in face_locations:
        shape = pose_predictor_68_point(image, face_location)
        #face_encodings_list.append(np.array(face_encoder.compute_face_descriptor(image, shape, num_jitters=1)))
        shape = face_utils.shape_to_np(shape)
        landmarks_list.append(shape)
    
    face_locations = transform(image, face_locations)
    return  {"facelocations":face_locations, "landmarklist":landmarks_list}

def easy_face_reco(frame, ):
    rgb_small_frame = frame[:, :, ::-1]
    data= encode_face(rgb_small_frame)
    if data:
        face_locations_list=data["facelocations"]
        landmarks_list=data["landmarklist"]
        name = "Unknown"
            
        if len(face_locations_list)>0:
            for (top, right, bottom, left) in face_locations_list:
                color = (0, 255, 0) #if name != "Unknown" else (0, 0, 255)  # Green for known, Red for unknown
                #cv2.rectangle(frame, (left, top), (right, bottom), color, 2)
                #cv2.rectangle(frame, (left, bottom - 30), (right, bottom), color, cv2.FILLED)
                cv2.putText(frame, name, (left + 2, bottom - 2), cv2.FONT_HERSHEY_SIMPLEX, 1, color,2)

        #landmarks visualization
        # for shape in landmarks_list:
        #     for (x, y) in shape:
        #         cv2.circle(frame, (x, y), 1, (255, 0, 255), -1)

if __name__ == '__main__':
    


    

    video_capture = cv2.VideoCapture("../../cv/face_recognition/videos/vid2.mp4")
    print('[INFO] Webcam well started')
    print('[INFO] Detecting...')

    while True:
        ret, frame = video_capture.read()
        if not ret:
            print("[ERROR] Failed to capture image from webcam.")
            break

        easy_face_reco(frame)
        cv2.imshow('Easy Facial Recognition App', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    print('[INFO] Stopping System')
    video_capture.release()
    cv2.destroyAllWindows()
# Out:
# [INFO] Starting System...
# [INFO] Importing pretrained model...
# [INFO] Pretrained model imported.
# [INFO] Webcam well started
# [INFO] Detecting...
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in the image.
# [ERROR] Failed to capture image from webcam.
# [INFO] Stopping System

# %%
import os

import PIL.Image
import cv2
import dlib
import numpy as np
from imutils import face_utils
from pathlib import Path
import PIL
class LandMarkDatasetMaker:
    def __init__(self,dataset_path,landmark_weight_path,fr_weight_path,directory_to_save) :
        self.root=Path(dataset_path)
        all_names=os.listdir(dataset_path)
        self.data=self.set_data_paths(all_names=all_names)
        self.landmark_weight_path=landmark_weight_path
        self.fr_weight_path=fr_weight_path
        self.directory_to_save=Path(directory_to_save)
        self.load_pretrained_weight()


    def load_pretrained_weight(self):
        try:
            self.pose_predictor_68_point = dlib.shape_predictor(self.landmark_weight_path)
            self.face_encoder = dlib.face_recognition_model_v1(self.fr_weight_path)
            self.face_detector = dlib.get_frontal_face_detector()
            print(f"weight loaded successfully")
        except  Exception as e:
            print(f"loading weight exception occur {e}")

    def set_data_paths(self,all_names):
        data_paths={}
        for name in all_names:
            new_path=self.root.joinpath(name)
            images_path=list(new_path.rglob("*.jpg")) + list(new_path.rglob("*.png"))
            data_paths[name]=images_path
        return data_paths
    def get_data(self,):
        return self.data
    def get_gray_img(self,image):
        gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
        return gray_image

    def get_transform_image(self,image):
        assert len(image.shape) == 3, f"[ERROR] The input image does not have three dimensions. Current shape: {image.shape}"
        
        if image.shape[2] == 4:
            image = cv2.cvtColor(image, cv2.COLOR_RGBA2RGB)
        elif image.shape[2] == 3:
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        elif image.shape[2] == 1:
            image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
        else:
            assert False,f"[ERROR] Unsupported number of channels: {image.shape[2]}." 
        
        if image.dtype != np.uint8:
            image = image.astype(np.uint8)
        gray_image=self.get_gray_img(image)
        return gray_image
    def make_landmark_list(self,face_locations,image):
        landmarks_list = []
        for face_location in face_locations:
            try: 
                shape = self.pose_predictor_68_point(image, face_location)
                #face_encodings_list.append(np.array(face_encoder.compute_face_descriptor(image, shape, num_jitters=1)))
                shape = face_utils.shape_to_np(shape)
                landmarks_list.append(shape) 
            except Exception as e:
                print(f"exception:{e}")
        return landmarks_list     
    def get_face_landmarks(self,image)->list:
        
    
            

        # Ensure the image is in the correct format

        gray_image=self.get_transform_image(image)
        
        face_locations=list()
        try:
            face_locations =self.face_detector(gray_image, 1)
        except Exception as e:
            print(f"[ERROR] Failed to detect faces. Error: {e}")
            return []

        if len(face_locations) == 0:
            print("[WARNING] No faces detected in the image.")
            return []

        return  self.make_landmark_list(face_locations,image)
    def save_landmarks(self, landmarks, img_path)->None:
        user_directory = self.directory_to_save / Path(img_path).parent.name
        
        if not user_directory.exists():
            user_directory.mkdir(parents=True, exist_ok=True)
        
        # Save landmarks as .npy file
        save_path = user_directory / (Path(img_path).stem + "_landmarks.npy")
        np.save(save_path, landmarks)
        print(f"[INFO] Landmarks saved for {img_path} at {save_path}")
    def save_landmarks_of_all_images(self,)->None:
        
        for user_name in self.data:
            for img_path in self.data[user_name]:
                image = PIL.Image.open(img_path)
                image = np.array(image)
                
                # Check if the image is empty or has an unexpected shape
                if image.size == 0:
                    print(f"[ERROR] The image {img_path} is empty or cannot be read.")
                    continue
                
                landmark_list =self.get_face_landmarks(image)
                if len( landmark_list)==0:
                    print(f"[WARNING] No faces detected in {img_path}. Skipping this file.")
                    continue 
                self.save_landmarks(landmark_list, img_path)


        
         
        
obj=LandMarkDatasetMaker(
    "../face_recognition/dataset_not_for_upload_images",
    "pretrained_model/shape_predictor_68_face_landmarks.dat",
    "pretrained_model/dlib_face_recognition_resnet_model_v1.dat",
    "./dataset_not_for_upload_images"
    )
obj.save_landmarks_of_all_images()
# Out:
# weight loaded successfully
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_0_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_0_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_100_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_100_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_101_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_101_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_102_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_102_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_103_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_103_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_104_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_104_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_105_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_105_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_106_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_106_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_107_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_107_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_108_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_108_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_109_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_109_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_10_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_10_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_110_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_110_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_111_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_111_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_112_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_112_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_113_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_113_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_114_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_114_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_115_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_115_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_116_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_116_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_117_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_117_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_118_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_118_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_119_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_119_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_11_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_11_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_120_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_120_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_121_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_121_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_122_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_122_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_123_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_123_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_124_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_124_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_125_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_125_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_126_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_126_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_127_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_127_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_128_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_128_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_129_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_129_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_12_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_12_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_13_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_13_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_14_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_14_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_15_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_15_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_16_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_16_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_17_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_17_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_18_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_18_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_19_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_19_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_1_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_1_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_20_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_20_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_21_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_21_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_22_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_22_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_23_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_23_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_24_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_24_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_25_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_25_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_26_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_26_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_27_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_27_0_landmarks.npy
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_27_1.png. Skipping this file.
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_28_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_28_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_29_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_29_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_2_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_2_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_30_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_30_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_31_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_31_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_32_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_32_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_33_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_33_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_34_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_34_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_35_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_35_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_36_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_36_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_37_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_37_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_38_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_38_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_39_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_39_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_3_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_3_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_40_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_40_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_41_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_41_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_42_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_42_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_43_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_43_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_44_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_44_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_45_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_45_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_46_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_46_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_47_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_47_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_48_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_48_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_49_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_49_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_4_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_4_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_50_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_50_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_51_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_51_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_52_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_52_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_53_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_53_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_54_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_54_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_55_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_55_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_56_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_56_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_57_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_57_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_58_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_58_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_59_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_59_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_5_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_5_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_60_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_60_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_61_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_61_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_62_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_62_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_63_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_63_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_64_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_64_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_65_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_65_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_66_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_66_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_67_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_67_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_68_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_68_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_69_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_69_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_6_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_6_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_70_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_70_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_71_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_71_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_72_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face_72_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Abdullah Munir\cropped_face_73_0.png at dataset_not_for_upload_images\Abdullah Munir\cropped_face
0.png. Skipping this file.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_409_0.png. Skipping this file.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_410_0.png. Skipping this file.
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_411_0.png at dataset_not_for_upload_images\Zehra\cropped_face_411_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_412_0.png at dataset_not_for_upload_images\Zehra\cropped_face_412_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_413_0.png at dataset_not_for_upload_images\Zehra\cropped_face_413_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_414_0.png at dataset_not_for_upload_images\Zehra\cropped_face_414_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_415_0.png at dataset_not_for_upload_images\Zehra\cropped_face_415_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_416_0.png at dataset_not_for_upload_images\Zehra\cropped_face_416_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_417_0.png at dataset_not_for_upload_images\Zehra\cropped_face_417_0_landmarks.npy
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_418_0.png. Skipping this file.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_419_0.png. Skipping this file.
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_420_0.png at dataset_not_for_upload_images\Zehra\cropped_face_420_0_landmarks.npy
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_421_0.png. Skipping this file.
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_422_0.png at dataset_not_for_upload_images\Zehra\cropped_face_422_0_landmarks.npy
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_423_0.png. Skipping this file.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_424_0.png. Skipping this file.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_425_0.png. Skipping this file.
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_426_0.png at dataset_not_for_upload_images\Zehra\cropped_face_426_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_427_0.png at dataset_not_for_upload_images\Zehra\cropped_face_427_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_428_0.png at dataset_not_for_upload_images\Zehra\cropped_face_428_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_429_0.png at dataset_not_for_upload_images\Zehra\cropped_face_429_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_430_0.png at dataset_not_for_upload_images\Zehra\cropped_face_430_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_431_0.png at dataset_not_for_upload_images\Zehra\cropped_face_431_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_432_0.png at dataset_not_for_upload_images\Zehra\cropped_face_432_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_433_0.png at dataset_not_for_upload_images\Zehra\cropped_face_433_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_434_0.png at dataset_not_for_upload_images\Zehra\cropped_face_434_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_435_0.png at dataset_not_for_upload_images\Zehra\cropped_face_435_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_436_0.png at dataset_not_for_upload_images\Zehra\cropped_face_436_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_437_0.png at dataset_not_for_upload_images\Zehra\cropped_face_437_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_438_0.png at dataset_not_for_upload_images\Zehra\cropped_face_438_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_439_0.png at dataset_not_for_upload_images\Zehra\cropped_face_439_0_landmarks.npy
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_440_0.png. Skipping this file.
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_441_0.png at dataset_not_for_upload_images\Zehra\cropped_face_441_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_442_0.png at dataset_not_for_upload_images\Zehra\cropped_face_442_0_landmarks.npy
# [INFO] Landmarks saved for ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_446_0.png at dataset_not_for_upload_images\Zehra\cropped_face_446_0_landmarks.npy
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_447_0.png. Skipping this file.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_449_0.png. Skipping this file.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_452_1.png. Skipping this file.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_92_2.png. Skipping this file.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_93_2.png. Skipping this file.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_94_2.png. Skipping this file.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_95_3.png. Skipping this file.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_98_3.png. Skipping this file.
# [WARNING] No faces detected in the image.
# [WARNING] No faces detected in ..\face_recognition\dataset_not_for_upload_images\Zehra\cropped_face_99_3.png. Skipping this file.

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 LandMarkDatasetMaker("../face_recognition/dataset_not_for_upload")
#
# Cell In[4], line 7, in LandMarkDatasetMaker.__init__(self, dataset_path)
#       5 self.root=Path(dataset_path)
#       6 all_names=os.listdir(dataset_path)
# ----> 7 self.data=self.set_data_paths(all_names=all_names)
#
# Cell In[4], line 13, in LandMarkDatasetMaker.set_data_paths(self, all_names)
#      11 for name in all_names:
#      12     new_path=self.root.joinpath(name)
# ---> 13     images_path=new_path.glob("*.jpg") + new_path.glob("*.png")
#      14     data_paths[name]=images_path
#      15 return data_paths
#
# TypeError: unsupported operand type(s) for +: 'generator' and 'generator'
